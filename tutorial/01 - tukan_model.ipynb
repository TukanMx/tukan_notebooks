# %% [markdown]
# ## Imports and setup
#
# First, let's make the standard imports.

# %%
import requests 
import pandas as pd
import json
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
from matplotlib import cm

token = "c4a583a30d7b08d569921c820673531b6019eee6" # Your TOKEN goes here
url = 'http://api.tukanmx.com/v1/retrieve/'

headers = {
"Content-Type": "application/json",
"Authorization": "Token " + token
}

# %% [markdown]
# ## Structure of TUKAN's data model
#
# Our data repository works as follows:
#
# *   **Institutions** - the source of the information, and the highest level on our repository.
#       *   **Tables** - the dataset that contains the information. Each dataset is associated to an institution or source.
#           * **Variables** - the indicators contained in the dataset.
#
# ### Institutions
#
# Institutions are the source of the information. These include governemnt and non-government entities that publish the original or raw-data, such as: INEGI, Banco de México, CONSAR, etc.
#
# You can easily query which institutions are available in our data catalog with the following query:

# %%
response = requests.request("GET", url = "http://api.tukanmx.com/v1/institutions/", headers=headers)
institutions = pd.DataFrame(response.json())
institutions
# Out:
#                id                                               name  \
# 0     mex_banxico                                    Banco de México
# 1   mex_grupo_bmv                          Bolsa Mexicana de Valores
# 2        mex_cnbv            Comisión Nacional Bancaria y de Valores
# 3        mex_cnsf             Comisión Nacional de Seguros y Fianzas
# 4      mex_consar  Comisión Nacional del Sistema de Ahorro para e...
# 5    mex_condusef  Comisión Nacional para la Protección y Defensa...
# 6       mex_inegi      Instituto Nacional de Estadística y Geografía
# 7         mex_sct         Secretaría de Comunicaciones y Transportes
# 8       mex_segob                          Secretaría de Gobernación
# 9        mex_shcp           Secretaría de Hacienda y Crédito Público
# 10     mex_sectur                              Secretaría de Turismo
# 11         wd_wjp                              World Justice Project
#
#      acronym                                        description  \
# 0    Banxico  Banco central mexicano. Las finalidades sustan...
# 1        BMV  La Bolsa de Valores de México es una entidad f...
# 2       CNBV  Un órgano desconcentrado de la Secretaría de H...
# 3       CNSF  La Comisión Nacional de Seguros y Fianzas es u...
# 4     CONSAR  CONSAR es la Comisión Nacional del Sistema de ...
# 5   CONDUSEF  Es la encargada de promover y difundir la educ...
# 6      INEGI  Organismo público autónomo responsable de norm...
# 7        SCT  Una de las secretarías de Estado que integran ...
# 8      SEGOB  La Secretaría de Gobernación atiende el desarr...
# 9       SHCP  La Secretaría de Hacienda y Crédito Público ti...
# 10    SECTUR  Es la encargada de diseñar e implementar las p...
# 11       WJP  The World Justice Project (Proyecto de Justici...
#
#                                        description_en  \
# 0   Mexico's central bank, monetary authority and ...
# 1   The BMV is a private financial entity that ope...
# 2   A decentralized body of the Ministry of Financ...
# 3   The National Insurance and Surety Commission i...
# 4   CONSAR is the regulator in charge of managing ...
# 5   Is in charge of promoting transparency and res...
# 6   The National Statistical and Geographic Inform...
# 7   One of the state secretariats that make up the...
# 8   SEGOB attends to the political devlopment of t...
# 9   The SHCP's (Ministry of Finance) mission is to...
# 10  Is in charge of designing and implementing the...
# 11  The World Justice Project (WJP) is an independ...
#
#                                   website country
# 0             https://www.banxico.org.mx/     mex
# 1                 https://www.bmv.com.mx/     mex
# 2                 https://www.gob.mx/cnbv     mex
# 3                 https://www.gob.mx/cnsf     mex
# 4              https://www.gob.mx/consar/     mex
# 5             https://www.gob.mx/condusef     mex
# 6   https://www.inegi.org.mx/default.html     mex
# 7                  https://www.gob.mx/sct     mex
# 8                https://www.gob.mx/segob     mex
# 9                 https://www.gob.mx/shcp     mex
# 10              https://www.gob.mx/sectur     mex
# 11       https://worldjusticeproject.org/      wd

# %% [markdown]
# The columns represent:
#
# |column| description|
# |--|--|
# |id| the TUKAN institution id|
# |name| the official name of the institution|
# |acronym| the common acronym associated to the instituion|
# |description| a brief overview of the instituion's main functions in Spanish|
# |description_en| a brief overview of the instituion's main functions in English|
# |website| the official website of the institution|
# |country*| the 3-letter ISO code of where the institution is based|
#
# *If `country == wd` then the institution is an international organization.
#
# ### Tables
#
# These are the datasets that contain the information. Each table is associated to an institution or source, and has a unique structure depending on the data it contains (don't worry we'll explain this more in detail later).
#
# First, we need to understand which tables are associated to each source. We can do this through two different methods: 1) we use the Explore component on the [web-application](https://dashboard.tukanmx.com/) or 2) we query directly the tables associated to a particular institution.
#
# For example, if you wanted to know which tables are associated to the INEGI, **you will need the institution's id** and then run the following code:

# %%
# Define a function for future use
def get_institution_tables(inst_id):

    global url
    global headers

    payload = {
    "type":"institution",
    "institution": inst_id,
    "operation": "data_tables_info"
    }

    response = requests.request("POST", url, headers=headers, data = json.dumps(payload))
    tables = pd.DataFrame(response.json()['data_tables'])
  
    return(tables)

get_institution_tables("mex_inegi").head(5)
# Out:
#                             id  \
# 0     mex_inegi_api_employment
# 1   mex_inegi_api_unemployment
# 2  mex_inegi_census_households
# 3      mex_inegi_census_people
# 4        mex_inegi_econ_census
#
#                                                 name  \
# 0                 Estadísticas de Ocupación y Empleo
# 1                               Tasa de Desocupación
# 2  Censo Población y Vivienda - Indicadores de Vi...
# 3  Censo Población y Vivienda - Indicadores Pobla...
# 4                                    Censo Económico
#
#                           name_en  \
# 0           Employment Statistics
# 1               Unemployment Rate
# 2   Census - Household Indicators
# 3  Census - Population Indicators
# 4                 Economic Census
#
#                                          description  \
# 0  Con base en la Encuesta Nacional de Ocupación ...
# 1  Tasa de desocupación en series desestacionaliz...
# 2  Proporciona la cuenta y características princi...
# 3  Proporciona la cuenta y características princi...
# 4  Los censos económicos contienen información ec...
#
#                                       description_en      mode  \
# 0  Based on the National Occupation and Employmen...  standard
# 1  Unemployment rate, seasonally adjusted and tre...  standard
# 2  Provides information on the main characteristi...  standard
# 3  Provides information on the main characteristi...  standard
# 4  The economic census contains economic informat...  standard
#
#                                              website last_updated  \
# 0   https://www.inegi.org.mx/temas/empleo/#Tabulados   2021-01-22
# 1             https://www.inegi.org.mx/temas/empleo/   2021-01-22
# 2  https://www.inegi.org.mx/programas/ccpv/2020/#...   2021-03-25
# 3  https://www.inegi.org.mx/programas/ccpv/2020/#...   2021-03-25
# 4  https://www.inegi.org.mx/programas/ce/2019/#In...   2021-08-27
#
#            data_updated institution_id  frequency_id tag_id  \
# 0  2021-08-19T06:45:05Z      mex_inegi     quarterly   None
# 1  2021-09-28T06:19:06Z      mex_inegi       monthly   None
# 2  1977-06-08T05:20:00Z      mex_inegi   decennially   None
# 3  1977-06-08T05:20:00Z      mex_inegi   decennially   None
# 4  2021-08-27T15:23:29Z      mex_inegi  quinquennial   None
#
#                                      categories
# 0                             [adjustment_type]
# 1                             [adjustment_type]
# 2                                   [geography]
# 3                              [geography, sex]
# 4  [company_size, economic_activity, geography]

# %% [markdown]
# This dictionary allows us to see all of the table's metadata, such as: its description, name, frequency, etc.
#
# In essence, the columns represent:
#
# |column| description|
# |--|--|
# |id| the TUKAN table id|
# |name| the name of the table in Spanish|
# |name_en| the name of the table in English|
# |description| a brief description of the table in Spanish|
# |description_en| a brief description of the table in English|
# |mode| internal TUKAN metadata|
# |website| the url from where the table was obtained|
# |last_updated| the date when the data was last updated|
# |institution_id| the TUKAN institution id|
# |frequency_id| the frequency of the data|
# |categories| a list of TUKAN categories associated to the table|
#
# There are four main metadata items that you need to be aware of: `id`, `website`, `frequency_id` and `categories`. By being aware of these four attributes, you'll be able to have a full understanding of the table's structure and how to extract it properly. In summary:
#
# *   The `id` is required to query the table's data and variable dictionary.
# *   The `website` allows you to validate the data with the original source.
# *   The `frequency_id` gives you information regarding the table's periodicity, i.e., monthly, quarterly, or daily data.
#
# **Categories**, on the other hand, deserve a notebook of their own. We explore this in-depth in the following notebook.
